# %% [markdown]
# # Train Detectors
#
# In this notebook we will train an detector using MMDetection.

# %% [markdown]
# ## Prepare the Dataset
#
# We have already prepared a dataset, a tiny subset from the KITTI autonomous driving datset.
#
# Our task is to detect pedestrian, cars, etc from street view images.
#
# To download and extract the dataset, in command line:
#
# ```
# curl https://download.openmmlab.com/mmdetection/data/kitti_tiny.zip -o kitti_tiny.zip
# unzip -d data kitti_tiny.zip
# ```
#
# The dataset contain *image files*, *label files* and *train/test splits*.

# %% [markdown]
# ## Format the Dataset

# %% [markdown]
# Definition of Kitti annotation can be found [here](https://github.com/bostondiditeam/kitti/blob/master/resources/devkit_object/readme.txt#L46).
#
# To train with MMDetection, we need to generate an annotation file with the following format.
#
# ```python
# [
#     {
#         'filename': 'a.jpg',
#         'width': 1280,
#         'height': 720,
#         'ann': {
#             'bboxes': <np.ndarray, float32> (n, 4),
#             'labels': <np.ndarray, int64> (n, ),
#             'bboxes_ignore': <np.ndarray, float32> (k, 4),
#             'labels_ignore': <np.ndarray, int64> (k, ) (optional field)
#         }
#     },
#     ...
# ]
# ```

# %%
import mmcv
import numpy as np

CLASSES = []
data_infos = []

for idx in range(75):
    imfile = f"data/kitti_tiny/training/image_2/{idx:06d}.jpeg"
    annfile = f"data/kitti_tiny/training/label_2/{idx:06d}.txt"

    image = mmcv.imread(imfile)
    height, width = image.shape[:2]

    ann = mmcv.list_from_file(annfile)

    gt_bboxes = []
    gt_labels = []
    gt_bboxes_ignore = []

    for line in ann:
        line = line.split(' ')
        bbox = [float(line[i]) for i in range(4,8)]
        
        if line[0] == 'DontCare':
            gt_bboxes_ignore.append(bbox)
        else:
            gt_bboxes.append(bbox)
            if line[0] not in CLASSES:
                CLASSES.append(line[0])
            gt_labels.append(CLASSES.index(line[0]))

    data_infos.append(
        dict(
            filename=f"{idx:06d}.jpeg",
            width=width,
            height=height,
            ann = dict(
                bboxes=np.array(gt_bboxes, dtype=np.float32).reshape(-1,4),
                labels=np.array(gt_labels, dtype=np.int64).reshape(-1),
                bboxes_ignore=np.array(gt_bboxes_ignore, dtype=np.float32).reshape(-1,4),
            )
    ))
    
print(CLASSES)
mmcv.dump(data_infos[:50], 'data/kitti_tiny/train_ann.pkl')
mmcv.dump(data_infos[50:], 'data/kitti_tiny/test_ann.pkl')
# Out:
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# ['Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram', 'Person_sitting']

# %% [markdown]
# ## Prepare a Config and Checkpoint File
#
# We choose to use RetinaNet.
#
# Use mim to download the config file and checkpoint file.
#
# ```
# mim download mmcls --config retinanet_r18_fpn_1x_coco --dest .
# mv retinanet_r18_fpn_1x_coco.py retinanet_r18_fpn_1x_kitti.py
# ```
#
# If you prefer to play with other models, navigate to [MMDetection model zoo](https://github.com/open-mmlab/mmdetection#overview-of-benchmark-and-model-zoo).

# %%
# !mim download mmdet --config retinanet_r18_fpn_1x_coco --dest .
# Out:
# processing retinanet_r18_fpn_1x_coco...
# retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth exists in C:\wangruohui\桌面\sjtu-openmmlab-tutorial
# Successfully dumped retinanet_r18_fpn_1x_coco.py to C:\wangruohui\桌面\sjtu-openmmlab-tutorial
# C:\Users\wangruohui\Miniconda3\envs\mm\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %% [markdown]
# ## Modify the Config File
#
# 1. Remove some intermediate item for clean: `dataset_type`, `img_norm_cfg`, `train_pipeline`, `test_pipeline`
# 1. Modify model
#     1. number of class in `bbox_head`: from 80 to 8
#     2. `inif_cfg`: to None
#     3. `load_from`: to the checkpoint we downloaded
# 1. Data: for train/val/test
#     1. `type`: `CocoDataset` -> `CustomDataset`
#     2. `prefix`, which is the root path to images: modify to `"data/kitti_tiny/training/image_2/"`
#     3. `ann_file`, the pickle file we just generates: modify to `data/kitti_tiny/train_ann.pkl` for training subset and `data/kitti_tiny/val_ann.pkl` for validation / test subset
#     4. `evaluation.metric`: to `'mAP'`, which is designed for `CustomDataset`
# 1. Runner and Optimizer
#     1. `optimizer.lr`: decrease learning rates based on linear scaling rule and for fine-tuning.
#     1. `lr_config`, decrease `warmup_iters` as we don't have that much iters for small dataset.
# 1. Misc
#     1. Decrease `log_confg.interval` for more logs
#     1. Increase `checkpoint_config.interval` to avoid saving too many checkpoints, to save time and disk space

# %% [markdown]
# ## Launch Training
#
# In command line
#
# ```
# mim train mmdet retinanet_r18_fpn_1x_kitti.py
# ```

# %%
# !mim train mmdet retinanet_r18_fpn_1x_kitti_v1.py
# Out:
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# Training command is /home/cine/miniconda3/envs/mmlab1/bin/python /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/.mim/tools/train.py retinanet_r18_fpn_1x_kitti_v1.py --launcher none --gpus 1.
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/utils/setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/.mim/tools/train.py:155: UserWarning: `--gpus` is deprecated because we only support single GPU mode in non-distributed training. Use `gpus=1` now.
#   warnings.warn('`--gpus` is deprecated because we only support '
# fatal: not a git repository (or any of the parent directories): .git
# 2023-02-09 00:58:53,943 - mmdet - INFO - Environment info:
# ------------------------------------------------------------
# sys.platform: linux
# Python: 3.8.16 (default, Jan 17 2023, 23:13:24) [GCC 11.2.0]
# CUDA available: True
# GPU 0: NVIDIA GeForce GTX 1080 Ti
# CUDA_HOME: /home/cine/miniconda3/envs/mmlab1
# NVCC: Cuda compilation tools, release 11.6, V11.6.124
# GCC: gcc (Ubuntu 11.3.0-1ubuntu1~22.04) 11.3.0
# PyTorch: 1.6.0
# PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v1.5.0 (Git Hash e2ac1fac44c5078ca927cb9b90e1b3066a0b2ed0)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 10.2
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 7.6.5
#   - Magma 2.5.2
#   - Build settings: BLAS=MKL, BUILD_TYPE=Release, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DUSE_VULKAN_WRAPPER -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, USE_CUDA=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_STATIC_DISPATCH=OFF,
#
# TorchVision: 0.7.0
# OpenCV: 4.7.0
# MMCV: 1.7.1
# MMCV Compiler: GCC 7.3
# MMCV CUDA Compiler: 10.2
# MMDetection: 2.28.1+
# ------------------------------------------------------------
#
# 2023-02-09 00:58:54,127 - mmdet - INFO - Distributed training: False
# 2023-02-09 00:58:54,297 - mmdet - INFO - Config:
# model = dict(
#     type='RetinaNet',
#     backbone=dict(
#         type='ResNet',
#         depth=18,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch'),
#     neck=dict(
#         type='FPN',
#         in_channels=[64, 128, 256, 512],
#         out_channels=256,
#         start_level=1,
#         add_extra_convs='on_input',
#         num_outs=5),
#     bbox_head=dict(
#         type='RetinaHead',
#         num_classes=8,
#         in_channels=256,
#         stacked_convs=4,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             octave_base_scale=4,
#             scales_per_octave=3,
#             ratios=[0.5, 1.0, 2.0],
#             strides=[8, 16, 32, 64, 128]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='FocalLoss',
#             use_sigmoid=True,
#             gamma=2.0,
#             alpha=0.25,
#             loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     train_cfg=dict(
#         assigner=dict(
#             type='MaxIoUAssigner',
#             pos_iou_thr=0.5,
#             neg_iou_thr=0.4,
#             min_pos_iou=0,
#             ignore_iof_thr=-1),
#         allowed_border=-1,
#         pos_weight=-1,
#         debug=False),
#     test_cfg=dict(
#         nms_pre=1000,
#         min_bbox_size=0,
#         score_thr=0.05,
#         nms=dict(type='nms', iou_threshold=0.5),
#         max_per_img=100))
# load_from = 'retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth'
# data = dict(
#     samples_per_gpu=2,
#     workers_per_gpu=2,
#     train=dict(
#         type='CustomDataset',
#         ann_file='data/kitti_tiny/train_ann.pkl',
#         img_prefix='data/kitti_tiny/training/image_2',
#         classes=[
#             'Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram',
#             'Person_sitting'
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ]),
#     val=dict(
#         type='CustomDataset',
#         ann_file='data/kitti_tiny/test_ann.pkl',
#         img_prefix='data/kitti_tiny/training/image_2',
#         classes=[
#             'Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram',
#             'Person_sitting'
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]),
#     test=dict(
#         type='CustomDataset',
#         ann_file='data/kitti_tiny/test_ann.pkl',
#         img_prefix='data/kitti_tiny/training/image_2',
#         classes=[
#             'Pedestrian', 'Truck', 'Car', 'Cyclist', 'Misc', 'Van', 'Tram',
#             'Person_sitting'
#         ],
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ]))
# evaluation = dict(interval=3, metric='mAP')
# optimizer = dict(type='SGD', lr=0.001, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='step',
#     warmup='linear',
#     warmup_iters=50,
#     warmup_ratio=0.001,
#     step=[8, 11])
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=3)
# log_config = dict(interval=3, hooks=[dict(type='TextLoggerHook')])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# resume_from = None
# workflow = [('train', 1)]
# opencv_num_threads = 0
# mp_start_method = 'fork'
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# work_dir = './work_dirs/retinanet_r18_fpn_1x_kitti_v1'
# auto_resume = False
# gpu_ids = range(0, 1)
#
# 2023-02-09 00:58:54,299 - mmdet - INFO - Set random seed to 463113937, deterministic: False
# 2023-02-09 00:58:54,504 - mmcv - INFO - initialize ResNet with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2023-02-09 00:58:54,614 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,615 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,615 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,616 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,617 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,618 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,619 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,620 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2023-02-09 00:58:54,626 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2023-02-09 00:58:54,651 - mmcv - INFO - initialize RetinaHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'retina_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2023-02-09 00:58:54,706 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,706 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,706 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,706 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,706 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,706 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,707 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([128, 64, 1, 1]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([256, 128, 1, 1]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,708 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 512, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# ConstantInit: val=0, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 128, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 256, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,709 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 512, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# neck.fpn_convs.4.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# neck.fpn_convs.4.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.cls_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.reg_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of RetinaNet
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.retina_cls.weight - torch.Size([72, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.retina_cls.bias - torch.Size([72]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.retina_reg.weight - torch.Size([36, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2023-02-09 00:58:54,710 - mmcv - INFO -
# bbox_head.retina_reg.bias - torch.Size([36]):
# NormalInit: mean=0, std=0.01, bias=0
#
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/datasets/custom.py:181: UserWarning: CustomDataset does not support filtering empty gt images.
#   warnings.warn(
# fatal: not a git repository (or any of the parent directories): .git
# 2023-02-09 00:58:55,962 - mmdet - INFO - Automatic scaling of learning rate (LR) has been disabled.
# 2023-02-09 00:58:55,966 - mmdet - INFO - load checkpoint from local path: retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth
# 2023-02-09 00:58:56,141 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for bbox_head.retina_cls.weight: copying a param with shape torch.Size([720, 256, 3, 3]) from checkpoint, the shape in current model is torch.Size([72, 256, 3, 3]).
# size mismatch for bbox_head.retina_cls.bias: copying a param with shape torch.Size([720]) from checkpoint, the shape in current model is torch.Size([72]).
# 2023-02-09 00:58:56,145 - mmdet - INFO - Start running, host: cine@cine-prof, work_dir: /home/cine/Documents/sjtu-openmmlab-tutorial-main/work_dirs/retinanet_r18_fpn_1x_kitti_v1
# 2023-02-09 00:58:56,145 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2023-02-09 00:58:56,145 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# 2023-02-09 00:58:56,145 - mmdet - INFO - Checkpoints will be saved to /home/cine/Documents/sjtu-openmmlab-tutorial-main/work_dirs/retinanet_r18_fpn_1x_kitti_v1 by HardDiskBackend.
# 2023-02-09 00:58:58,849 - mmdet - INFO - Epoch [1][3/25]	lr: 4.096e-05, eta: 0:04:22, time: 0.884, data_time: 0.698, memory: 713, loss_cls: 1.1808, loss_bbox: 0.2273, loss: 1.4081
# 2023-02-09 00:58:59,166 - mmdet - INFO - Epoch [1][6/25]	lr: 1.009e-04, eta: 0:02:25, time: 0.106, data_time: 0.021, memory: 713, loss_cls: 1.1576, loss_bbox: 0.2018, loss: 1.3594
# 2023-02-09 00:58:59,474 - mmdet - INFO - Epoch [1][9/25]	lr: 1.608e-04, eta: 0:01:46, time: 0.103, data_time: 0.020, memory: 713, loss_cls: 1.1480, loss_bbox: 0.1955, loss: 1.3435
# 2023-02-09 00:58:59,782 - mmdet - INFO - Epoch [1][12/25]	lr: 2.208e-04, eta: 0:01:26, time: 0.102, data_time: 0.020, memory: 713, loss_cls: 1.1073, loss_bbox: 0.2580, loss: 1.3653
# 2023-02-09 00:59:00,090 - mmdet - INFO - Epoch [1][15/25]	lr: 2.807e-04, eta: 0:01:14, time: 0.103, data_time: 0.019, memory: 727, loss_cls: 1.0546, loss_bbox: 0.3334, loss: 1.3880
# 2023-02-09 00:59:00,409 - mmdet - INFO - Epoch [1][18/25]	lr: 3.407e-04, eta: 0:01:06, time: 0.106, data_time: 0.019, memory: 727, loss_cls: 1.0137, loss_bbox: 0.2484, loss: 1.2621
# 2023-02-09 00:59:00,717 - mmdet - INFO - Epoch [1][21/25]	lr: 4.006e-04, eta: 0:01:00, time: 0.103, data_time: 0.020, memory: 727, loss_cls: 0.9550, loss_bbox: 0.2613, loss: 1.2163
# 2023-02-09 00:59:01,025 - mmdet - INFO - Epoch [1][24/25]	lr: 4.605e-04, eta: 0:00:55, time: 0.103, data_time: 0.019, memory: 727, loss_cls: 0.7905, loss_bbox: 0.1888, loss: 0.9793
# 2023-02-09 00:59:03,512 - mmdet - INFO - Epoch [2][3/25]	lr: 5.405e-04, eta: 0:01:09, time: 0.781, data_time: 0.698, memory: 727, loss_cls: 0.9223, loss_bbox: 0.1822, loss: 1.1045
# 2023-02-09 00:59:03,828 - mmdet - INFO - Epoch [2][6/25]	lr: 6.004e-04, eta: 0:01:05, time: 0.106, data_time: 0.019, memory: 727, loss_cls: 0.7378, loss_bbox: 0.2701, loss: 1.0079
# 2023-02-09 00:59:04,147 - mmdet - INFO - Epoch [2][9/25]	lr: 6.603e-04, eta: 0:01:01, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.5917, loss_bbox: 0.2438, loss: 0.8355
# 2023-02-09 00:59:04,459 - mmdet - INFO - Epoch [2][12/25]	lr: 7.203e-04, eta: 0:00:57, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.4408, loss_bbox: 0.2933, loss: 0.7341
# 2023-02-09 00:59:04,775 - mmdet - INFO - Epoch [2][15/25]	lr: 7.802e-04, eta: 0:00:54, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.5229, loss_bbox: 0.1446, loss: 0.6675
# 2023-02-09 00:59:05,087 - mmdet - INFO - Epoch [2][18/25]	lr: 8.402e-04, eta: 0:00:52, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.4492, loss_bbox: 0.2227, loss: 0.6719
# 2023-02-09 00:59:05,400 - mmdet - INFO - Epoch [2][21/25]	lr: 9.001e-04, eta: 0:00:50, time: 0.104, data_time: 0.019, memory: 727, loss_cls: 0.2115, loss_bbox: 0.2002, loss: 0.4117
# 2023-02-09 00:59:05,709 - mmdet - INFO - Epoch [2][24/25]	lr: 9.600e-04, eta: 0:00:48, time: 0.104, data_time: 0.021, memory: 727, loss_cls: 0.5788, loss_bbox: 0.2275, loss: 0.8062
# 2023-02-09 00:59:08,205 - mmdet - INFO - Epoch [3][3/25]	lr: 1.000e-03, eta: 0:00:54, time: 0.783, data_time: 0.697, memory: 727, loss_cls: 0.4583, loss_bbox: 0.1697, loss: 0.6281
# 2023-02-09 00:59:08,512 - mmdet - INFO - Epoch [3][6/25]	lr: 1.000e-03, eta: 0:00:52, time: 0.102, data_time: 0.020, memory: 727, loss_cls: 0.2720, loss_bbox: 0.2717, loss: 0.5437
# 2023-02-09 00:59:08,820 - mmdet - INFO - Epoch [3][9/25]	lr: 1.000e-03, eta: 0:00:50, time: 0.103, data_time: 0.020, memory: 727, loss_cls: 0.5884, loss_bbox: 0.1760, loss: 0.7644
# 2023-02-09 00:59:09,131 - mmdet - INFO - Epoch [3][12/25]	lr: 1.000e-03, eta: 0:00:48, time: 0.103, data_time: 0.019, memory: 727, loss_cls: 0.3331, loss_bbox: 0.1753, loss: 0.5084
# 2023-02-09 00:59:09,450 - mmdet - INFO - Epoch [3][15/25]	lr: 1.000e-03, eta: 0:00:46, time: 0.107, data_time: 0.020, memory: 727, loss_cls: 0.4234, loss_bbox: 0.2225, loss: 0.6459
# 2023-02-09 00:59:09,764 - mmdet - INFO - Epoch [3][18/25]	lr: 1.000e-03, eta: 0:00:45, time: 0.104, data_time: 0.019, memory: 727, loss_cls: 0.4024, loss_bbox: 0.2066, loss: 0.6090
# 2023-02-09 00:59:10,077 - mmdet - INFO - Epoch [3][21/25]	lr: 1.000e-03, eta: 0:00:43, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.3422, loss_bbox: 0.2093, loss: 0.5515
# 2023-02-09 00:59:10,388 - mmdet - INFO - Epoch [3][24/25]	lr: 1.000e-03, eta: 0:00:42, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1943, loss_bbox: 0.2379, loss: 0.4322
# 2023-02-09 00:59:10,481 - mmdet - INFO - Saving checkpoint at 3 epochs
# [                                                  ] 0/25, elapsed: 0s, ETA:/home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/core/utils/misc.py:145: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629395347/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   valid_idxs = torch.nonzero(valid_mask)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 31.9 task/s, elapsed: 1s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# 2023-02-09 00:59:12,036 - mmdet - INFO -
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 1103 | 0.923  | 0.441 |
# | Truck          | 3   | 113  | 1.000  | 0.126 |
# | Car            | 62  | 691  | 0.968  | 0.792 |
# | Cyclist        | 7   | 1    | 0.000  | 0.000 |
# | Misc           | 1   | 14   | 0.000  | 0.000 |
# | Van            | 11  | 297  | 0.818  | 0.180 |
# | Tram           | 5   | 226  | 0.400  | 0.004 |
# | Person_sitting | 5   | 0    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.193 |
# +----------------+-----+------+--------+-------+
# 2023-02-09 00:59:12,063 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti_v1.py
# 2023-02-09 00:59:12,064 - mmdet - INFO - Epoch(val) [3][25]	AP50: 0.1930, mAP: 0.1928
# 2023-02-09 00:59:14,469 - mmdet - INFO - Epoch [4][3/25]	lr: 1.000e-03, eta: 0:00:46, time: 0.784, data_time: 0.699, memory: 727, loss_cls: 0.2971, loss_bbox: 0.2008, loss: 0.4978
# 2023-02-09 00:59:14,778 - mmdet - INFO - Epoch [4][6/25]	lr: 1.000e-03, eta: 0:00:44, time: 0.103, data_time: 0.021, memory: 727, loss_cls: 0.2641, loss_bbox: 0.1796, loss: 0.4437
# 2023-02-09 00:59:15,088 - mmdet - INFO - Epoch [4][9/25]	lr: 1.000e-03, eta: 0:00:43, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.4014, loss_bbox: 0.1456, loss: 0.5469
# 2023-02-09 00:59:15,404 - mmdet - INFO - Epoch [4][12/25]	lr: 1.000e-03, eta: 0:00:42, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.2781, loss_bbox: 0.2321, loss: 0.5102
# 2023-02-09 00:59:15,715 - mmdet - INFO - Epoch [4][15/25]	lr: 1.000e-03, eta: 0:00:40, time: 0.103, data_time: 0.020, memory: 727, loss_cls: 0.3998, loss_bbox: 0.2090, loss: 0.6088
# 2023-02-09 00:59:16,030 - mmdet - INFO - Epoch [4][18/25]	lr: 1.000e-03, eta: 0:00:39, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.2379, loss_bbox: 0.1999, loss: 0.4378
# 2023-02-09 00:59:16,346 - mmdet - INFO - Epoch [4][21/25]	lr: 1.000e-03, eta: 0:00:38, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.2017, loss_bbox: 0.1294, loss: 0.3311
# 2023-02-09 00:59:16,650 - mmdet - INFO - Epoch [4][24/25]	lr: 1.000e-03, eta: 0:00:37, time: 0.102, data_time: 0.019, memory: 727, loss_cls: 0.2472, loss_bbox: 0.1929, loss: 0.4402
# 2023-02-09 00:59:19,164 - mmdet - INFO - Epoch [5][3/25]	lr: 1.000e-03, eta: 0:00:39, time: 0.790, data_time: 0.703, memory: 727, loss_cls: 0.2624, loss_bbox: 0.1332, loss: 0.3957
# 2023-02-09 00:59:19,473 - mmdet - INFO - Epoch [5][6/25]	lr: 1.000e-03, eta: 0:00:38, time: 0.103, data_time: 0.021, memory: 727, loss_cls: 0.2582, loss_bbox: 0.1437, loss: 0.4018
# 2023-02-09 00:59:19,784 - mmdet - INFO - Epoch [5][9/25]	lr: 1.000e-03, eta: 0:00:37, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.2735, loss_bbox: 0.1580, loss: 0.4315
# 2023-02-09 00:59:20,099 - mmdet - INFO - Epoch [5][12/25]	lr: 1.000e-03, eta: 0:00:36, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.1474, loss_bbox: 0.1555, loss: 0.3029
# 2023-02-09 00:59:20,416 - mmdet - INFO - Epoch [5][15/25]	lr: 1.000e-03, eta: 0:00:35, time: 0.107, data_time: 0.021, memory: 727, loss_cls: 0.1923, loss_bbox: 0.1983, loss: 0.3906
# 2023-02-09 00:59:20,739 - mmdet - INFO - Epoch [5][18/25]	lr: 1.000e-03, eta: 0:00:34, time: 0.107, data_time: 0.019, memory: 727, loss_cls: 0.1934, loss_bbox: 0.2139, loss: 0.4073
# 2023-02-09 00:59:21,056 - mmdet - INFO - Epoch [5][21/25]	lr: 1.000e-03, eta: 0:00:33, time: 0.107, data_time: 0.020, memory: 727, loss_cls: 0.1972, loss_bbox: 0.1644, loss: 0.3616
# 2023-02-09 00:59:21,371 - mmdet - INFO - Epoch [5][24/25]	lr: 1.000e-03, eta: 0:00:32, time: 0.105, data_time: 0.018, memory: 727, loss_cls: 0.2227, loss_bbox: 0.2144, loss: 0.4371
# 2023-02-09 00:59:23,879 - mmdet - INFO - Epoch [6][3/25]	lr: 1.000e-03, eta: 0:00:34, time: 0.788, data_time: 0.701, memory: 727, loss_cls: 0.2011, loss_bbox: 0.2066, loss: 0.4077
# 2023-02-09 00:59:24,203 - mmdet - INFO - Epoch [6][6/25]	lr: 1.000e-03, eta: 0:00:33, time: 0.108, data_time: 0.019, memory: 727, loss_cls: 0.1159, loss_bbox: 0.0822, loss: 0.1981
# 2023-02-09 00:59:24,519 - mmdet - INFO - Epoch [6][9/25]	lr: 1.000e-03, eta: 0:00:32, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.1910, loss_bbox: 0.1115, loss: 0.3026
# 2023-02-09 00:59:24,832 - mmdet - INFO - Epoch [6][12/25]	lr: 1.000e-03, eta: 0:00:31, time: 0.106, data_time: 0.019, memory: 727, loss_cls: 0.1574, loss_bbox: 0.1419, loss: 0.2994
# 2023-02-09 00:59:25,145 - mmdet - INFO - Epoch [6][15/25]	lr: 1.000e-03, eta: 0:00:30, time: 0.103, data_time: 0.019, memory: 727, loss_cls: 0.2569, loss_bbox: 0.1911, loss: 0.4480
# 2023-02-09 00:59:25,466 - mmdet - INFO - Epoch [6][18/25]	lr: 1.000e-03, eta: 0:00:29, time: 0.107, data_time: 0.019, memory: 727, loss_cls: 0.1571, loss_bbox: 0.2076, loss: 0.3647
# 2023-02-09 00:59:25,784 - mmdet - INFO - Epoch [6][21/25]	lr: 1.000e-03, eta: 0:00:28, time: 0.106, data_time: 0.020, memory: 727, loss_cls: 0.1901, loss_bbox: 0.1936, loss: 0.3837
# 2023-02-09 00:59:26,097 - mmdet - INFO - Epoch [6][24/25]	lr: 1.000e-03, eta: 0:00:27, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1798, loss_bbox: 0.1615, loss: 0.3413
# 2023-02-09 00:59:26,196 - mmdet - INFO - Saving checkpoint at 6 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 31.4 task/s, elapsed: 1s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# 2023-02-09 00:59:27,729 - mmdet - INFO -
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 511  | 0.923  | 0.805 |
# | Truck          | 3   | 310  | 1.000  | 0.667 |
# | Car            | 62  | 705  | 0.984  | 0.784 |
# | Cyclist        | 7   | 174  | 0.571  | 0.032 |
# | Misc           | 1   | 112  | 0.000  | 0.000 |
# | Van            | 11  | 259  | 0.909  | 0.336 |
# | Tram           | 5   | 225  | 0.400  | 0.010 |
# | Person_sitting | 5   | 0    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.329 |
# +----------------+-----+------+--------+-------+
# 2023-02-09 00:59:27,760 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti_v1.py
# 2023-02-09 00:59:27,760 - mmdet - INFO - Epoch(val) [6][25]	AP50: 0.3290, mAP: 0.3292
# 2023-02-09 00:59:30,169 - mmdet - INFO - Epoch [7][3/25]	lr: 1.000e-03, eta: 0:00:28, time: 0.785, data_time: 0.701, memory: 727, loss_cls: 0.2102, loss_bbox: 0.1639, loss: 0.3741
# 2023-02-09 00:59:30,488 - mmdet - INFO - Epoch [7][6/25]	lr: 1.000e-03, eta: 0:00:27, time: 0.107, data_time: 0.019, memory: 727, loss_cls: 0.1863, loss_bbox: 0.1956, loss: 0.3819
# 2023-02-09 00:59:30,795 - mmdet - INFO - Epoch [7][9/25]	lr: 1.000e-03, eta: 0:00:27, time: 0.102, data_time: 0.018, memory: 727, loss_cls: 0.1225, loss_bbox: 0.1257, loss: 0.2482
# 2023-02-09 00:59:31,103 - mmdet - INFO - Epoch [7][12/25]	lr: 1.000e-03, eta: 0:00:26, time: 0.104, data_time: 0.019, memory: 727, loss_cls: 0.1515, loss_bbox: 0.1132, loss: 0.2647
# 2023-02-09 00:59:31,423 - mmdet - INFO - Epoch [7][15/25]	lr: 1.000e-03, eta: 0:00:25, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.1693, loss_bbox: 0.1968, loss: 0.3661
# 2023-02-09 00:59:31,735 - mmdet - INFO - Epoch [7][18/25]	lr: 1.000e-03, eta: 0:00:24, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1423, loss_bbox: 0.1393, loss: 0.2816
# 2023-02-09 00:59:32,048 - mmdet - INFO - Epoch [7][21/25]	lr: 1.000e-03, eta: 0:00:24, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.2335, loss_bbox: 0.1345, loss: 0.3680
# 2023-02-09 00:59:32,354 - mmdet - INFO - Epoch [7][24/25]	lr: 1.000e-03, eta: 0:00:23, time: 0.102, data_time: 0.019, memory: 727, loss_cls: 0.2040, loss_bbox: 0.1491, loss: 0.3531
# 2023-02-09 00:59:34,871 - mmdet - INFO - Epoch [8][3/25]	lr: 1.000e-03, eta: 0:00:23, time: 0.789, data_time: 0.701, memory: 727, loss_cls: 0.1919, loss_bbox: 0.2051, loss: 0.3970
# 2023-02-09 00:59:35,190 - mmdet - INFO - Epoch [8][6/25]	lr: 1.000e-03, eta: 0:00:22, time: 0.106, data_time: 0.019, memory: 727, loss_cls: 0.1883, loss_bbox: 0.2074, loss: 0.3957
# 2023-02-09 00:59:35,502 - mmdet - INFO - Epoch [8][9/25]	lr: 1.000e-03, eta: 0:00:22, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1040, loss_bbox: 0.1069, loss: 0.2109
# 2023-02-09 00:59:35,812 - mmdet - INFO - Epoch [8][12/25]	lr: 1.000e-03, eta: 0:00:21, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1697, loss_bbox: 0.1889, loss: 0.3586
# 2023-02-09 00:59:36,126 - mmdet - INFO - Epoch [8][15/25]	lr: 1.000e-03, eta: 0:00:20, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1480, loss_bbox: 0.1133, loss: 0.2613
# 2023-02-09 00:59:36,444 - mmdet - INFO - Epoch [8][18/25]	lr: 1.000e-03, eta: 0:00:19, time: 0.106, data_time: 0.020, memory: 727, loss_cls: 0.1552, loss_bbox: 0.1426, loss: 0.2978
# 2023-02-09 00:59:36,754 - mmdet - INFO - Epoch [8][21/25]	lr: 1.000e-03, eta: 0:00:19, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1146, loss_bbox: 0.1181, loss: 0.2327
# 2023-02-09 00:59:37,071 - mmdet - INFO - Epoch [8][24/25]	lr: 1.000e-03, eta: 0:00:18, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.1178, loss_bbox: 0.1342, loss: 0.2519
# 2023-02-09 00:59:39,565 - mmdet - INFO - Epoch [9][3/25]	lr: 1.000e-04, eta: 0:00:18, time: 0.782, data_time: 0.699, memory: 727, loss_cls: 0.1905, loss_bbox: 0.1567, loss: 0.3471
# 2023-02-09 00:59:39,884 - mmdet - INFO - Epoch [9][6/25]	lr: 1.000e-04, eta: 0:00:17, time: 0.106, data_time: 0.020, memory: 727, loss_cls: 0.0982, loss_bbox: 0.1245, loss: 0.2227
# 2023-02-09 00:59:40,199 - mmdet - INFO - Epoch [9][9/25]	lr: 1.000e-04, eta: 0:00:17, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.1332, loss_bbox: 0.1405, loss: 0.2737
# 2023-02-09 00:59:40,512 - mmdet - INFO - Epoch [9][12/25]	lr: 1.000e-04, eta: 0:00:16, time: 0.104, data_time: 0.021, memory: 727, loss_cls: 0.1335, loss_bbox: 0.1385, loss: 0.2720
# 2023-02-09 00:59:40,818 - mmdet - INFO - Epoch [9][15/25]	lr: 1.000e-04, eta: 0:00:15, time: 0.103, data_time: 0.020, memory: 727, loss_cls: 0.1594, loss_bbox: 0.1023, loss: 0.2617
# 2023-02-09 00:59:41,135 - mmdet - INFO - Epoch [9][18/25]	lr: 1.000e-04, eta: 0:00:15, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.1031, loss_bbox: 0.1492, loss: 0.2523
# 2023-02-09 00:59:41,449 - mmdet - INFO - Epoch [9][21/25]	lr: 1.000e-04, eta: 0:00:14, time: 0.106, data_time: 0.020, memory: 727, loss_cls: 0.1449, loss_bbox: 0.1521, loss: 0.2969
# 2023-02-09 00:59:41,762 - mmdet - INFO - Epoch [9][24/25]	lr: 1.000e-04, eta: 0:00:13, time: 0.104, data_time: 0.018, memory: 727, loss_cls: 0.1301, loss_bbox: 0.1338, loss: 0.2640
# 2023-02-09 00:59:41,860 - mmdet - INFO - Saving checkpoint at 9 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 31.5 task/s, elapsed: 1s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# 2023-02-09 00:59:43,396 - mmdet - INFO -
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 463  | 0.923  | 0.786 |
# | Truck          | 3   | 245  | 1.000  | 0.792 |
# | Car            | 62  | 608  | 0.968  | 0.786 |
# | Cyclist        | 7   | 334  | 0.571  | 0.043 |
# | Misc           | 1   | 104  | 0.000  | 0.000 |
# | Van            | 11  | 253  | 0.909  | 0.323 |
# | Tram           | 5   | 121  | 0.400  | 0.036 |
# | Person_sitting | 5   | 0    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.346 |
# +----------------+-----+------+--------+-------+
# 2023-02-09 00:59:43,426 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti_v1.py
# 2023-02-09 00:59:43,426 - mmdet - INFO - Epoch(val) [9][25]	AP50: 0.3460, mAP: 0.3458
# 2023-02-09 00:59:45,836 - mmdet - INFO - Epoch [10][3/25]	lr: 1.000e-04, eta: 0:00:13, time: 0.787, data_time: 0.701, memory: 727, loss_cls: 0.1198, loss_bbox: 0.1770, loss: 0.2968
# 2023-02-09 00:59:46,151 - mmdet - INFO - Epoch [10][6/25]	lr: 1.000e-04, eta: 0:00:13, time: 0.104, data_time: 0.021, memory: 727, loss_cls: 0.1802, loss_bbox: 0.1689, loss: 0.3491
# 2023-02-09 00:59:46,470 - mmdet - INFO - Epoch [10][9/25]	lr: 1.000e-04, eta: 0:00:12, time: 0.106, data_time: 0.020, memory: 727, loss_cls: 0.1458, loss_bbox: 0.1771, loss: 0.3229
# 2023-02-09 00:59:46,781 - mmdet - INFO - Epoch [10][12/25]	lr: 1.000e-04, eta: 0:00:11, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1329, loss_bbox: 0.1320, loss: 0.2649
# 2023-02-09 00:59:47,102 - mmdet - INFO - Epoch [10][15/25]	lr: 1.000e-04, eta: 0:00:11, time: 0.107, data_time: 0.019, memory: 727, loss_cls: 0.1374, loss_bbox: 0.1640, loss: 0.3013
# 2023-02-09 00:59:47,422 - mmdet - INFO - Epoch [10][18/25]	lr: 1.000e-04, eta: 0:00:10, time: 0.107, data_time: 0.020, memory: 727, loss_cls: 0.1316, loss_bbox: 0.1049, loss: 0.2365
# 2023-02-09 00:59:47,736 - mmdet - INFO - Epoch [10][21/25]	lr: 1.000e-04, eta: 0:00:09, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1041, loss_bbox: 0.0875, loss: 0.1916
# 2023-02-09 00:59:48,047 - mmdet - INFO - Epoch [10][24/25]	lr: 1.000e-04, eta: 0:00:09, time: 0.104, data_time: 0.021, memory: 727, loss_cls: 0.1137, loss_bbox: 0.1354, loss: 0.2491
# 2023-02-09 00:59:50,562 - mmdet - INFO - Epoch [11][3/25]	lr: 1.000e-04, eta: 0:00:08, time: 0.788, data_time: 0.700, memory: 727, loss_cls: 0.1361, loss_bbox: 0.1709, loss: 0.3070
# 2023-02-09 00:59:50,875 - mmdet - INFO - Epoch [11][6/25]	lr: 1.000e-04, eta: 0:00:08, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1069, loss_bbox: 0.1014, loss: 0.2084
# 2023-02-09 00:59:51,181 - mmdet - INFO - Epoch [11][9/25]	lr: 1.000e-04, eta: 0:00:07, time: 0.103, data_time: 0.020, memory: 727, loss_cls: 0.1553, loss_bbox: 0.1527, loss: 0.3080
# 2023-02-09 00:59:51,498 - mmdet - INFO - Epoch [11][12/25]	lr: 1.000e-04, eta: 0:00:07, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.1596, loss_bbox: 0.1511, loss: 0.3107
# 2023-02-09 00:59:51,809 - mmdet - INFO - Epoch [11][15/25]	lr: 1.000e-04, eta: 0:00:06, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1305, loss_bbox: 0.0940, loss: 0.2244
# 2023-02-09 00:59:52,128 - mmdet - INFO - Epoch [11][18/25]	lr: 1.000e-04, eta: 0:00:05, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.0892, loss_bbox: 0.0898, loss: 0.1790
# 2023-02-09 00:59:52,441 - mmdet - INFO - Epoch [11][21/25]	lr: 1.000e-04, eta: 0:00:05, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.1135, loss_bbox: 0.1129, loss: 0.2265
# 2023-02-09 00:59:52,750 - mmdet - INFO - Epoch [11][24/25]	lr: 1.000e-04, eta: 0:00:04, time: 0.103, data_time: 0.020, memory: 727, loss_cls: 0.1119, loss_bbox: 0.1109, loss: 0.2227
# 2023-02-09 00:59:55,274 - mmdet - INFO - Epoch [12][3/25]	lr: 1.000e-05, eta: 0:00:04, time: 0.790, data_time: 0.702, memory: 727, loss_cls: 0.1549, loss_bbox: 0.1662, loss: 0.3211
# 2023-02-09 00:59:55,582 - mmdet - INFO - Epoch [12][6/25]	lr: 1.000e-05, eta: 0:00:03, time: 0.104, data_time: 0.020, memory: 727, loss_cls: 0.1510, loss_bbox: 0.1195, loss: 0.2705
# 2023-02-09 00:59:55,899 - mmdet - INFO - Epoch [12][9/25]	lr: 1.000e-05, eta: 0:00:03, time: 0.105, data_time: 0.019, memory: 727, loss_cls: 0.0769, loss_bbox: 0.1281, loss: 0.2049
# 2023-02-09 00:59:56,213 - mmdet - INFO - Epoch [12][12/25]	lr: 1.000e-05, eta: 0:00:02, time: 0.105, data_time: 0.021, memory: 727, loss_cls: 0.1399, loss_bbox: 0.1069, loss: 0.2469
# 2023-02-09 00:59:56,532 - mmdet - INFO - Epoch [12][15/25]	lr: 1.000e-05, eta: 0:00:01, time: 0.106, data_time: 0.019, memory: 727, loss_cls: 0.2045, loss_bbox: 0.1755, loss: 0.3800
# 2023-02-09 00:59:56,841 - mmdet - INFO - Epoch [12][18/25]	lr: 1.000e-05, eta: 0:00:01, time: 0.103, data_time: 0.020, memory: 727, loss_cls: 0.1397, loss_bbox: 0.1260, loss: 0.2656
# 2023-02-09 00:59:57,157 - mmdet - INFO - Epoch [12][21/25]	lr: 1.000e-05, eta: 0:00:00, time: 0.105, data_time: 0.020, memory: 727, loss_cls: 0.1428, loss_bbox: 0.1595, loss: 0.3023
# 2023-02-09 00:59:57,469 - mmdet - INFO - Epoch [12][24/25]	lr: 1.000e-05, eta: 0:00:00, time: 0.104, data_time: 0.019, memory: 727, loss_cls: 0.1512, loss_bbox: 0.1821, loss: 0.3332
# 2023-02-09 00:59:57,579 - mmdet - INFO - Saving checkpoint at 12 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 32.3 task/s, elapsed: 1s, ETA:     0s
# ---------------iou_thr: 0.5---------------
# 2023-02-09 00:59:59,114 - mmdet - INFO -
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 390  | 0.923  | 0.794 |
# | Truck          | 3   | 227  | 1.000  | 0.792 |
# | Car            | 62  | 612  | 0.984  | 0.795 |
# | Cyclist        | 7   | 341  | 0.571  | 0.039 |
# | Misc           | 1   | 114  | 0.000  | 0.000 |
# | Van            | 11  | 302  | 0.909  | 0.310 |
# | Tram           | 5   | 134  | 0.400  | 0.062 |
# | Person_sitting | 5   | 0    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.349 |
# +----------------+-----+------+--------+-------+
# 2023-02-09 00:59:59,142 - mmdet - INFO - Exp name: retinanet_r18_fpn_1x_kitti_v1.py
# 2023-02-09 00:59:59,142 - mmdet - INFO - Epoch(val) [12][25]	AP50: 0.3490, mAP: 0.3489
# Training finished successfully.

# %% [markdown]
# ## Understand Logs
#
#
# The log is long but mainly contains the following parts:
#
# 1. Toolbox information
# 2. Dumped Config files
# 3. Model Initialization Logs
#     1. Check `mmdet - INFO - load checkpoint from local path: retinanet_r18_fpn_1x_coco_20220407_171055-614fd399.pth`, which means pretrained weights are loaded correctly.
# 4. Information on Hooks: we don't configure this explicitly in this tutorial, so ignore that
# 5. Training progress
#     1. Training logs: including current learning, training loss, time consumption, memory occupation
#     2. Validation logs: meanAP on validation set
# ```

# %% [markdown]
# ## Test the Model
#
# The trained model (checkpoint file) is usually saved under `work_dirs/{experiment_name}/latest.pth`.
# We can load it to test with a new image.

# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot

image = 'data/kitti_tiny/training/image_2/000066.jpeg'
model = init_detector('retinanet_r18_fpn_1x_kitti_v1.py', 'work_dirs/retinanet_r18_fpn_1x_kitti_v1/latest.pth')
result = inference_detector(model, image)
show_result_pyplot(model, image, result)
# Out:
# load checkpoint from local path: work_dirs/retinanet_r18_fpn_1x_kitti_v1/latest.pth
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/datasets/utils.py:66: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/core/utils/misc.py:145: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629395347/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   valid_idxs = torch.nonzero(valid_mask)

# %%
# !mim test mmdet retinanet_r18_fpn_1x_kitti.py --checkpoint work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth --eval mAP
# !mim test mmdet retinanet_r18_fpn_1x_kitti.py --checkpoint work_dirs/retinanet_r18_fpn_1x_kitti/latest.pth --show-dir work_dirs
# !mim test mmdet retinanet_r18_fpn_1x_kitti_v1.py --checkpoint work_dirs/retinanet_r18_fpn_1x_kitti_v1/latest.pth --show-dir work_dirs --eval mAP
# Out:
# Testing command is /home/cine/miniconda3/envs/mmlab1/bin/python /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/.mim/tools/test.py retinanet_r18_fpn_1x_kitti_v1.py work_dirs/retinanet_r18_fpn_1x_kitti_v1/latest.pth --launcher none --show-dir work_dirs --eval mAP.
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/utils/setup_env.py:38: UserWarning: Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# /home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/utils/setup_env.py:48: UserWarning: Setting MKL_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
#   warnings.warn(
# load checkpoint from local path: work_dirs/retinanet_r18_fpn_1x_kitti_v1/latest.pth
# [                                                  ] 0/25, elapsed: 0s, ETA:/home/cine/miniconda3/envs/mmlab1/lib/python3.8/site-packages/mmdet/core/utils/misc.py:145: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629395347/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   valid_idxs = torch.nonzero(valid_mask)
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 25/25, 7.9 task/s, elapsed: 3s, ETA:     0s
# ---------------iou_thr: 0.5---------------
#
# +----------------+-----+------+--------+-------+
# | class          | gts | dets | recall | ap    |
# +----------------+-----+------+--------+-------+
# | Pedestrian     | 13  | 390  | 0.923  | 0.794 |
# | Truck          | 3   | 227  | 1.000  | 0.792 |
# | Car            | 62  | 612  | 0.984  | 0.795 |
# | Cyclist        | 7   | 341  | 0.571  | 0.039 |
# | Misc           | 1   | 114  | 0.000  | 0.000 |
# | Van            | 11  | 302  | 0.909  | 0.310 |
# | Tram           | 5   | 134  | 0.400  | 0.062 |
# | Person_sitting | 5   | 0    | 0.000  | 0.000 |
# +----------------+-----+------+--------+-------+
# | mAP            |     |      |        | 0.349 |
# +----------------+-----+------+--------+-------+
# OrderedDict([('AP50', 0.349), ('mAP', 0.34894418716430664)])
# Testing finished successfully.
